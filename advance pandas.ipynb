# %%
#advance pandas
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\harsh kasana\Downloads\placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()  #by default, values till five will be shown
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.head(22) # can also show desired values
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# 5   8.77          6.19       1
# 6   5.34          7.09       0
# 7   6.56          6.29       0
# 8   6.32          6.71       0
# 9   7.69          7.12       1
# 10  6.18          6.35       0
# 11  5.44          6.54       0
# 12  6.09          7.01       0
# 13  8.50          5.09       1
# 14  7.51          6.25       1
# 15  8.88          5.93       1
# 16  8.04          7.64       1
# 17  7.81          8.71       1
# 18  5.94          5.88       0
# 19  6.75          8.11       1
# 20  5.80          8.06       0
# 21  6.53          7.64       0

# %%
df.tail() # it will show by default last five values
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.tail(2)
# Out:
#     cgpa  resume_score  placed
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.count() #will also count repeated values
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df2= pd.read_csv(r"C:\Users\harsh kasana\Downloads\tested titanic 3 december 2025.csv")

# %%
df2.count()
# Out:
# PassengerId    418
# Survived       418
# Pclass         418
# Name           418
# Sex            418
# Age            332
# SibSp          418
# Parch          418
# Ticket         418
# Fare           417
# Cabin           91
# Embarked       418
# dtype: int64

# %%
df2.info()   #object refer to text value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df = df.drop(columns=['', 'Salary'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df.shape  #(total rows,total column)
# Out:
# (418, 12)

# %%
df2['Embarked'].value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
(df2['Cabin'].value_counts()).sort_values()
# Out:
# Cabin
# D15                1
# D34                1
# G6                 1
# C28                1
# D43                1
#                   ..
# C89                2
# F4                 2
# B45                2
# C80                2
# B57 B59 B63 B66    3
# Name: count, Length: 76, dtype: int64

# %%
(df2['Embarked'].value_counts()).sort_values(ascending=False)  #ton show in descending order
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
df2.sort_values('Embarked') #table arranged according to the given column (Embarked)
# Out:
#      PassengerId  Survived  Pclass  \
# 208         1100         1       1
# 177         1069         0       1
# 179         1071         1       1
# 181         1073         0       1
# 184         1076         1       1
# ..           ...       ...     ...
# 228         1120         0       3
# 117         1009         1       3
# 226         1118         0       3
# 232         1124         0       3
# 248         1140         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 208                      Rosenbaum, Miss. Edith Louise  female  33.0      0
# 177                    Stengel, Mr. Charles Emil Henry    male  54.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 181                   Compton, Mr. Alexander Taylor Jr    male  37.0      1
# 184  Douglas, Mrs. Frederick Charles (Mary Helene B...  female  27.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.sort_values(['Embarked','Pclass'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df2.sort_values(['Embarked','Pclass'])
#
# NameError: name 'df2' is not defined

# %%
df2.drop_duplicates(['Sex'])
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
df2.drop_duplicates(subset=['Parch']).shape
# Out:
# (8, 12)

# %%
df1 = df2.groupby('Embarked')
df1

# %%
#length 
len(df2)
# Out:
# 418

# %%
df1.size()
# Out:
# Embarked
# C    102
# Q     46
# S    270
# dtype: int64

# %%
len(df1)
# Out:
# 3

# %%
df1.first()
# Out:
#           PassengerId  Survived  Pclass  \
# Embarked
# C                 900         1       3
# Q                 892         0       3
# S                 893         1       3
#
#                                                Name     Sex   Age  SibSp  \
# Embarked
# C         Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# Q                                  Kelly, Mr. James    male  34.5      0
# S                  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#           Parch  Ticket    Fare            Cabin
# Embarked
# C             0    2657  7.2292  B57 B59 B63 B66
# Q             0  330911  7.8292              C78
# S             0  363272  7.0000              B45

# %%
df2.rename(columns={'Sex':'Gender'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df2.rename(index={0:'first entry',1:'second entry'})
# Out:
#               PassengerId  Survived  Pclass  \
# first entry           892         0       3
# second entry          893         1       3
# 2                     894         0       2
# 3                     895         0       3
# 4                     896         1       3
# ...                   ...       ...     ...
# 413                  1305         0       3
# 414                  1306         1       1
# 415                  1307         0       3
# 416                  1308         0       3
# 417                  1309         0       3
#
#                                                       Name     Sex   Age  \
# first entry                               Kelly, Mr. James    male  34.5
# second entry              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                                Myles, Mr. Thomas Francis    male  62.0
# 3                                         Wirz, Mr. Albert    male  27.0
# ...

# %%
pd.concat([df2,df]) # concat is used to merge two dataframes together
# Out:
#     PassengerId  Survived  Pclass  \
# 0         892.0       0.0     3.0
# 1         893.0       1.0     3.0
# 2         894.0       0.0     2.0
# 3         895.0       0.0     3.0
# 4         896.0       1.0     3.0
# ..          ...       ...     ...
# 95          NaN       NaN     NaN
# 96          NaN       NaN     NaN
# 97          NaN       NaN     NaN
# 98          NaN       NaN     NaN
# 99          NaN       NaN     NaN
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                               Kelly, Mr. James    male  34.5    0.0    0.0
# 1               Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                      Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                               Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# ..                                           ...     ...   ...    ...    ...
# ...

# %%
df.join(df2) #work as concat but only shows common values in the result(not show null values)
# Out:
#     cgpa  resume_score  placed  PassengerId  Survived  Pclass  \
# 0   8.14          6.52       1          892         0       3
# 1   6.17          5.17       0          893         1       3
# 2   8.27          8.86       1          894         0       2
# 3   6.88          7.27       1          895         0       3
# 4   7.52          7.30       1          896         1       3
# ..   ...           ...     ...          ...       ...     ...
# 95  6.33          6.38       0          987         0       3
# 96  8.23          7.76       1          988         1       1
# 97  6.65          7.78       0          989         0       3
# 98  8.14          5.63       1          990         1       3
# 99  6.09          6.61       0          991         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# ...

# %%
df2.rename(columns={'Sex':'Gender'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2.rename(columns={'Sex':'Gender'})
#
# NameError: name 'df2' is not defined
