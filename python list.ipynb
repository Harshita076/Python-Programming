# %%
a=62
b=2
print(a/b)
# Out:
# 31.0

# %%
print(a//b)
# Out:
# 31

# %%
print(a%b)
# Out:
# 0

# %%
print(a**b)
# Out:
# 3844

# %%
x=5
x += 3
print(x)
# Out:
# 8

# %%
x=6
x -= 3
print(x)
# Out:
# 3

# %%
x=8
x /= 4
print(x)
# Out:
# 2.0

# %%
x=22
x *= 2
print(x)
# Out:
# 44

# %%
x=22
x %= 22
print(x)
# Out:
# 0

# %%
x=45
x **= 2
print(x)
# Out:
# 2025

# %%
x=33
x //=5
print(x)
# Out:
# 6

# %%
x=45
y=66
print(x == y)
# Out:
# False

# %%
print(x>=y)
# Out:
# False

# %%
print(x<=y)
# Out:
# True

# %%
7

# %%
x=5
print(x>3 and x<10)
# Out:
# True

# %%
x=15
print(not( x<6 and x>3))
# Out:
# True

# %%
x=34
print(x<45) and (x>45)
# Out:
# True

# %%
x=34
print(x>5 or x<45)
# Out:
# True

# %%
x=44
print(x<11 or x>5)
# Out:
# True

# %%
x=88
print(x<34 or x>56)
# Out:
# True

# %%
x=45
print(x>56 or x<4)
# Out:
# False

# %%
x=45
y=45
print('x' and ' y')
# Out:
#  y

# %%
x = ["apple" ,"banana"]
print("banana" in x)
print("banana" not in x)
# Out:
# True
# False

# %%
L1= ['a','b','c','d','a','b']

# %%
L1[1]
# Out:
# 'b'

# %%
L1[0:4]
# Out:
# ['a', 'b', 'c', 'd']

# %%
L1[3:5]
# Out:
# ['d', 'a']

# %%
L1[4]
# Out:
# 'a'

# %%
L1[:5]
# Out:
# ['a', 'b', 'c', 'd', 'a']

# %%
L1=['a','h',4,'f',True] #in true no double quote is used.
L2=['A','G','J','I']

# %%
L1[4],L2[3] #to print 2 variables from two/one list at a time use print or comma.
# Out:
# (True, 'I')

# %%
L1[0],L1[4]
# Out:
# ('a', True)

# %%
L1[-4]
# Out:
# 'h'

# %%
L1[-1]
# Out:
# True

# %%
L1[-4:-2]
# Out:
# ['h', 4]

# %%
L1[-4:-1]
# Out:
# ['h', 4, 'f']

# %%
sports =['volleyball','football','badminton','tennis']

# %%
sports[2]
# Out:
# 'badminton'

# %%
sports[-2:-4]
# Out:
# []

# %%
sports[2:4]
# Out:
# ['badminton', 'tennis']

# %%
sports[-5:-2]
# Out:
# ['volleyball', 'football']

# %%
sports[2:5]
# Out:
# ['badminton', 'tennis']

# %%
sports[:-3]
# Out:
# ['volleyball']

# %%
sports.append("cricket")
print(sports)
# Out:
# ['volleyball', 'football', 'badminton', 'tennis', 'cricket', 'cricket']

# %% [raw]
# sports.insert("3,table")
# print(sports)

# %%
sports.insert(3,"table")
print(sports)
# Out:
# ['volleyball', 'football', 'badminton', 'table', 'tennis', 'cricket', 'cricket']

# %%
material=['ball','net','badminton']

# %%
sports.extend(material)
print(sports)
# Out:
# ['volleyball', 'football', 'badminton', 'table', 'tennis', 'cricket', 'cricket', 'ball', 'net', 'badminton']

# %%
students = ['harshita','mehar','himanshi','manav','anup','haadiya']
teachers = ['nitish','dheeraj','gaurav','abhishek','khem']

# %%
#append
students.append('ansh')
print(students)
# Out:
# ['harshita', 'mehar', 'himanshi', 'manav', 'anup', 'haadiya', 'ansh', 'ansh', 'ansh']

# %%
#insert
students.insert(5,'ishu')
print (students)
# Out:
# ['harshita', 'mehar', 'himanshi', 'manav', 'anup', 'ishu', 'haadiya', 'ansh', 'ansh', 'ansh', 'nitish', 'dheeraj', 'gaurav', 'abhishek', 'khem']

# %%
#extend
students.extend(teachers)
print(students)
# Out:
# ['harshita', 'mehar', 'himanshi', 'manav', 'anup', 'haadiya', 'ansh', 'ansh', 'ansh', 'nitish', 'dheeraj', 'gaurav', 'abhishek', 'khem']

# %%
#remove
students.remove("himanshi")
print(students)
# Out:
# ['harshita', 'mehar', 'manav', 'anup', 'haadiya']

# %%
#pop
students.pop(4)
# Out:
# 'anup'

# %%
#delete
del  students()
print(students)
# Out:
#   Cell In[40], line 2
#     del  students()
#          ^
# SyntaxError: cannot delete function call

# %%
#remove
students.remove("harshita")
print(students)
# Out:
# ['mehar', 'himanshi', 'manav', 'anup', 'haadiya']

# %%
#max
print(max(students))
# Out:
# mehar

# %%
#min
print(min(students))
# Out:
# anup

# %%
#copy
L = ['a','b','c','d']
L1 =[ ]
L1=L.copy()
print(L1)
# Out:
# ['a', 'b', 'c', 'd']

# %%
students[2]
# Out:
# 'manav'

# %%
teachers = ['nitish','dheeraj','gaurav','abhishek','khem']

# %%
teachers[2]
# Out:
# 'gaurav'

# %%
teachers[1:4]
# Out:
# ['dheeraj', 'gaurav', 'abhishek']

# %%
teachers[-4:-2]
# Out:
# ['dheeraj', 'gaurav']

# %%
teachers[:-2]
# Out:
# ['nitish', 'dheeraj', 'gaurav']

# %%
sports = ['football','hockey','badminton','volleyball','basketball' ]
equipments = ['ball','hockey stick', 'net','cones','racket']

# %%
#append
sports.append("handball")
print(sports)
# Out:
# ['football', 'hockey', 'badminton', 'volleyball', 'basketball', 'handball']

# %%
#insert
sports.insert(4,"cricket")
print(sports)
# Out:
# ['football', 'hockey', 'badminton', 'volleyball', 'cricket', 'basketball', 'handball']

# %%
#extend
sports.extend(equipments)
print(sports)
# Out:
# ['football', 'hockey', 'badminton', 'volleyball', 'basketball', 'ball', 'hockey stick', 'net', 'cones', 'racket']

# %%
#remove
sports.remove("hockey")
print(sports)
# Out:
# ['football', 'badminton', 'volleyball', 'basketball']

# %%
#delete
del sports()
print(sports)
# Out:
#   Cell In[16], line 2
#     del sports()
#         ^
# SyntaxError: cannot delete function call

# %%
#pop
sports.pop(4)
# Out:
# 'basketball'

# %%
#max
print(max(sports))
# Out:
# volleyball

# %%
#min
print(min(sports))
# Out:
# badminton

# %%
#copy
sports2 = []
sports2 = sports.copy()
print(sports2)
# Out:
# ['football', 'hockey', 'badminton', 'volleyball', 'ball', 'hockey stick', 'net', 'cones', 'racket']

# %%
sports[2]
# Out:
# 'badminton'

# %%
sports[5]
# Out:
# 'hockey stick'

# %%
sports[2:6]
# Out:
# ['badminton', 'volleyball', 'ball', 'hockey stick']

# %%
sports[-9]
# Out:
# 'football'

# %%
sports[-5:-1]
# Out:
# ['ball', 'hockey stick', 'net', 'cones']

# %%
sports[:-4]
# Out:
# ['football', 'hockey', 'badminton', 'volleyball', 'ball']

# %%
#tuple
T1 = (2,5,8,9,8)

# %%
print(T1)
# Out:
# (2, 5, 8, 9, 8)

# %%
print(type(T1))
# Out:
# <class 'tuple'>

# %%
T2= ('A','B','C','G')

# %%
print(type(T2))
# Out:
# <class 'tuple'>

# %%
T2[3]
# Out:
# 'G'

# %%
T2[1:4]
# Out:
# ('B', 'C', 'G')

# %%
T2[-4]
# Out:
# 'A'

# %%
T2[-3:-1]
# Out:
# ('B', 'C')

# %%
#REVERSE ELEMENT
#T2[start:end:-1(step)]
T2[::-1]
# Out:
# ('G', 'C', 'B', 'A')

# %%
T2[::3]
print(T2)
# Out:
# ('A', 'B', 'C', 'G')

# %%
T2[::-2]
# Out:
# ('G', 'B')

# %%
T2= ('a','d','h','k','l') #to change anything in a tuple you have to convert it in list
y = list(T2)
print(y)
# Out:
# ['a', 'd', 'h', 'k', 'l']

# %%
y.insert(3,"K")
print(y)
# Out:
# ['a', 'd', 'h', 'K', 'K', 'k', 'l']

# %%
Harshita = (67,)
new = ('H',7,9,0,8)
print(type(Harshita))
type(new)
# Out:
# <class 'tuple'>
# tuple

# %%
t_1 = (5,8,9,7)    # addition of tuple
t_2= (6,9,8,9)
t1 = t_1 + t_2
print(t1)
# Out:
# (5, 8, 9, 7, 6, 9, 8, 9)

# %%
#remove items in tuple
t= (6,9,8,0)
h=list(t)
h.remove(9)
t=tuple(h)
print(h)
# Out:
# [6, 8, 0]
