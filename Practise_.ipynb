# %%
print(28)
print(34+67)
# Out:
# 28
# 101

# %%
name="harshita"
age=18
print('age')
# Out:
# age

# %%
print(age)
# Out:
# 18

# %%
print("my name is:",name)
print("my age is:",age)
# Out:
# my name is: harshita
# my age is: 18

# %% [raw]
# print("i am:",name)

# %%
2myvar= high  #a variable never starts with a number/integer
# Out:
#   Cell In[10], line 1
#     2myvar= high
#     ^
# SyntaxError: invalid decimal literal

# %%
printmy_var=("high")

# %%
age=23
old=False
a=None
print(type(a))
print(type(old))
# Out:
# <class 'NoneType'>
# <class 'bool'>

# %%
# Write code below
 # Write code below
a = int(input("enter a: "))  #don't leave space in starting or else it will cause error
b = int(input("enter b: "))
c = (a**2+b**2) ** 0.5
print(c)
# Out:
# enter a:  8
# enter b:  8
# 11.313708498984761

# %%
a = int(input("enter a: "))
b = int(input("enter b: "))
c = (a**2 + b**2) ** 0.5
print(c)
# Out:
# enter a:  2
# enter b:  4
# 4.47213595499958

# %%
# Write code below 
a=int(input("what do you have left in pesos?: "))
b=int(input("what do you have left in soles?: "))
c=int(input("what do you have left in reais?: "))
d= (a*0.18+b*0.28+c*0.28)
print(d)
# Out:
# what do you have left in pesos?:  6700
# what do you have left in soles?:  450
# what do you have left in reais?:  360
# 1432.8

# %%
#SyntaxError: this occurs when invalid Python code is present.
#NameError: this occurs when you're trying to use a variable without declaring it first.
#TypeError: this occurs when the data type you're using doesn't suit what you're trying to do.

# %%
grade=25
if grade>= 33:
    print("you passed")
else:
    print("you failed.")
# Out:
# you failed.

# %%
ph = int(input("enter a ph level (0-14):"))
if ph > 7:
  print("basic")
elif ph < 7:
  print("acidic")
else :
  print("neutral")
# Out:
# enter a ph level (0-14): 7
# neutral

# %%
# .randint is used for computer to choose any number or value from the given range. 💖
import random
num = random.randint(1,9)
print(num) # we do not use "" to represent variable here necause we need value of variable called num if use double quote to print num than it will print num it self rater than printing its value.

# %%
# Write code below 💖
import random
question = input("enter your question :")  #do this again mittar
random_number = random.randint(0,9)
if random_number == 1:
      anwer = 'yes - definitely'
elif random_number == 2:
   answer= "it is decidedly so."
elif random_number == 3: 
   answer = "without a doubt"
elif random_number == 4:
   answer = "reply hazy, try again"
elif random_number == 5:
  answer =  "ask again later."
elif random_number == 6:
  answer= "better not tell you now"
elif random_number == 7:
  answer ="my sources say no"
elif random_number == 8:
  answer = "outlook not so good"
elif random_number == 9:
  answer = "veru doubtful"
else:
   answer = 'error'
    
print('Magic 8 Ball:  ',answer)
# Out:
# enter your question : hjhhh
# Magic 8 Ball:   ask again later.

# %%
# Magic 8 Ball 🎱
# Codédex

import random

question = input('Question:      ')

random_number = random.randint(1, 9)

if random_number == 1:
  answer = 'Yes - definitely'
elif random_number == 2:
  answer = 'It is decidedly so'
elif random_number == 3:
  answer = 'Without a doubt'
elif random_number == 4:
  answer = 'Reply hazy, try again'
elif random_number == 5:
  answer = 'Ask again later'
elif random_number == 6:
  answer = 'Better not tell you now'
elif random_number == 7:
  answer = 'My sources say no'
elif random_number == 8:
  answer = 'Outlook not so good'
elif random_number == 9:
  answer = 'Very doubtful'
else:
  answer = 'Error'
  
print('Magic 8 Ball:  ' + answer)
# Out:
# Question:       is tomorrow good for me
# Magic 8 Ball:  Yes - definitely

# %%
h = [20,30,40,50]
temp = h[0]
h[0]=h[3]
h[3] = temp
print(h)
# Out:
# [50, 30, 40, 20]

# %%
temp1 = h[1]
h[1] = h[2]
h[2] = temp1
print(h)
# Out:
# [50, 30, 30, 20]

# %%
h[1],h[2] = h[2],h[1]
print(h)
# Out:
# [50, 40, 30, 20]
