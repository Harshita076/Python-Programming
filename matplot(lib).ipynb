# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,linestyle = "dotted")
plt.show()

# %%
y1 = np.array([8,1,3,10])
y2 = np.array([6,2,7,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
y1 = np.array([8,1,3,10])
plt.plot(y1,linewidth='20.5')
plt.show()

# %%
y1 = np.array([8,1,3,10])
plt.plot(y1,color = "r")
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.xlabel("Average pulse")
plt.ylabel("Calorie burned")
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.title("sports watch reading")
plt.xlabel("Average pulse")
plt.ylabel("Calorie burned")
# Out:
# Text(0, 0.5, 'Calorie burned')

# %%
#first plot
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1,2,1)
plt.plot(x,y)

#second plot
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y,color = "r")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y,width = 0.5)
plt.show()

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
plt.pie(y)
plt.show()

# %%
df= pd.read_csv(r"C:\Users\harsh kasana\Downloads\tested titanic 3 december 2025.csv")

# %%
import pandas as pd
import seaborn as sns

# %%
df= sns.load_dataset("Titanic")

# %%
#sactterplot
sns.scatterplot(x="age",y="fare",hue="sex",data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df.drop(["who"],axis=1,inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
#line plot
sns.lineplot(x="age",y="survived",data=df)
# Out:
# <Axes: xlabel='age', ylabel='survived'>

# %%
sns.relplot(x="age",y="fare",hue ="class",col="survived",data=df)

# %%
sns.histplot(df["fare"],bins=25)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.kdeplot(df["age"],fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(df["fare"],bins=30,kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.boxplot(x="embarked",y="fare",data=df)
# Out:
# <Axes: xlabel='embarked', ylabel='fare'>

# %%
sns.violinplot(x="sex",y="age",hue="survived",split=True,data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x="class",y="fare",hue="survived",data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.countplot(df["sex"])
# Out:
# <Axes: xlabel='count', ylabel='sex'>
